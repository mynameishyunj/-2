# %%
import numpy as np

np.nan
arr1 = np.array([1,2,3, np.nan, np.inf])
arr1 = np.arange(1.0,7)
arr2 = np.arange(10.0,70,10)

print('arr1: %s \t shape:%s' % (repr(arr1), arr1.shape))
print('arr2: %s \t shape:%s' % (repr(arr2), arr2.shape))
# Out:
# arr1: array([1., 2., 3., 4., 5., 6.]) 	 shape:(6,)
# arr2: array([10., 20., 30., 40., 50., 60.]) 	 shape:(6,)

# %%
arr1 + 100
# Out:
# array([101., 102., 103., 104., 105., 106.])

# %%
arr1 + arr2
# Out:
# array([11., 22., 33., 44., 55., 66.])

# %%
arr1 * 5
# Out:
# array([ 5., 10., 15., 20., 25., 30.])

# %%
arr1 * arr2
# Out:
# array([ 10.,  40.,  90., 160., 250., 360.])

# %%
#모듈(메모장??) 2가지
#패키지(폴더로)

# %%
random.randint
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-412707dec4cd> in <module>
# ----> 1 random.randint
#
# NameError: name 'random' is not defined

# %%
import 
fromjson import encoder

# %%
####외부 패키지 사용하는 방법1
:환경변수 추가가 되어있는 곳에 import 추가가능

####외부 패키지 사용하는 방법2
:import sys복사 후 sys. path
    
import sys

sys.path


#같은 파일의 경로 import 가능함
from my pakage import calc_modules
import mypakages


#아예 다른 경로에 있는 경우 환경 변수에 원하는 경로를 추가
# Out:
#   File "<ipython-input-138-10ca00667ff3>", line 2
#     :환경변수 추가가 되어있는 곳에 import 추가가능
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# # Series

# %%
s1 = pd.Series([1, 3, 5, np.nan, 6, 8])
s1
#라벨 + 1차원 데이터
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s1.values
# Out:
# array([ 1.,  3.,  5., nan,  6.,  8.])

# %% [markdown]
# #### numpy 배열을 사용하지만 object타입으로 이용할 경우 배열의 모든 원소의 데이터 타입이 달라도 됨

# %%
s1 = pd.Series([np.nan, np.inf, 0, 1, 2, 3, 'a', 'b', 'c'])
s1
#인덱스 부분     value  부분
# Out:
# 0    NaN
# 1    inf
# 2      0
# 3      1
# 4      2
# 5      3
# 6      a
# 7      b
# 8      c
# dtype: object

# %%
s1.values
# Out:
# array([nan, inf, 0, 1, 2, 3, 'a', 'b', 'c'], dtype=object)

# %% [markdown]
# # index 설정하기

# %%
index_seq = range(10,20)
seq_data = range(10)
s2 = pd.Series(data=seq_data, index=index_seq)

# data== 는 생략가능

s2
# Out:
# 10    0
# 11    1
# 12    2
# 13    3
# 14    4
# 15    5
# 16    6
# 17    7
# 18    8
# 19    9
# dtype: int64

# %%
index_date = ['2018-10-17', '2018-10-18', '2018-10-19', '2018-10-20']
s3 = pd.Series([200, 195, np.nan, 205], index=index_date)
s3
# Out:
# 2018-10-17    200.0
# 2018-10-18    195.0
# 2018-10-19      NaN
# 2018-10-20    205.0
# dtype: float64

# %%
s3.index
# Out:
# Index(['2018-10-17', '2018-10-18', '2018-10-19', '2018-10-20'], dtype='object')

# %% [markdown]
# # Dictionary로 시리즈 입력

# %%
# key->index(라벨링), value->value
dict_data = {
    '국어': 100,
    '영어': 95,
    '수학': 80
}
s5 = pd.Series(dict_data)
print(s5)
# Out:
# 국어    100
# 영어     95
# 수학     80
# dtype: int64

# %% [markdown]
# # 날짜 자동 생성 - date_range

# %%
pd.date_range('2019-05-25', '2019-05-28')
#frequency - 단위
# Out:
# DatetimeIndex(['2019-05-25', '2019-05-26', '2019-05-27', '2019-05-28'], dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2019-05-25', end='2019-05-28')
# Out:
# DatetimeIndex(['2019-05-25', '2019-05-26', '2019-05-27', '2019-05-28'], dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2019-05-25', periods=4)
# Out:
# DatetimeIndex(['2019-05-25', '2019-05-26', '2019-05-27', '2019-05-28'], dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2019-05-25 10:00:00', periods=6)
# Out:
# DatetimeIndex(['2019-05-25 10:00:00', '2019-05-26 10:00:00',
#                '2019-05-27 10:00:00', '2019-05-28 10:00:00',
#                '2019-05-29 10:00:00', '2019-05-30 10:00:00'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # 날짜 데이터 포맷 (yyyy-mm-dd)

# %%
date_index1 = pd.date_range(start='2019-05-25', periods=4)
date_index2 = pd.date_range(start='2019.05.25', periods=4)
date_index3 = pd.date_range(start='2019/05/25', periods=4)
print('date_index1: ', repr(date_index1))
print('date_index2: ', repr(date_index2))
print('date_index3: ', repr(date_index3))
# Out:
# date_index1:  DatetimeIndex(['2019-05-25', '2019-05-26', '2019-05-27', '2019-05-28'], dtype='datetime64[ns]', freq='D')
# date_index2:  DatetimeIndex(['2019-05-25', '2019-05-26', '2019-05-27', '2019-05-28'], dtype='datetime64[ns]', freq='D')
# date_index3:  DatetimeIndex(['2019-05-25', '2019-05-26', '2019-05-27', '2019-05-28'], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # date_range's time series Frequencies

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects
# 참고!

# %%
# 2 day
pd.date_range(start="2019-05-25", periods=8, freq='2D')
# Out:
# DatetimeIndex(['2019-05-25', '2019-05-27', '2019-05-29', '2019-05-31',
#                '2019-06-02', '2019-06-04', '2019-06-06', '2019-06-08'],
#               dtype='datetime64[ns]', freq='2D')

# %%
# business day
pd.date_range(start="2019-05-25", periods=8, freq='B')
# Out:
# DatetimeIndex(['2019-05-27', '2019-05-28', '2019-05-29', '2019-05-30',
#                '2019-05-31', '2019-06-03', '2019-06-04', '2019-06-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
# 3 week
pd.date_range(start="2019-05-25", periods=8, freq='3W')
# Out:
# DatetimeIndex(['2019-05-26', '2019-06-16', '2019-07-07', '2019-07-28',
#                '2019-08-18', '2019-09-08', '2019-09-29', '2019-10-20'],
#               dtype='datetime64[ns]', freq='3W-SUN')

# %%
# 월말 Month Last
pd.date_range(start="2019-05-25", periods=8, freq='M')
# Out:
# DatetimeIndex(['2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
# Buisness Month
pd.date_range(start="2019-05-25", periods=8, freq='BM')
# Out:
# DatetimeIndex(['2019-05-31', '2019-06-28', '2019-07-31', '2019-08-30',
#                '2019-09-30', '2019-10-31', '2019-11-29', '2019-12-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
# Buisness Month Start
pd.date_range(start="2019-05-25", periods=8, freq='BMS')
# Out:
# DatetimeIndex(['2019-06-03', '2019-07-01', '2019-08-01', '2019-09-02',
#                '2019-10-01', '2019-11-01', '2019-12-02', '2020-01-01'],
#               dtype='datetime64[ns]', freq='BMS')

# %%
# Quarter
pd.date_range(start="2019-05-25", periods=8, freq='Q')
# Out:
# DatetimeIndex(['2019-06-30', '2019-09-30', '2019-12-31', '2020-03-31',
#                '2020-06-30', '2020-09-30', '2020-12-31', '2021-03-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
# Year
pd.date_range(start="2019-05-25 10:10", periods=8, freq='A')
# Out:
# DatetimeIndex(['2019-12-31 10:10:00', '2020-12-31 10:10:00',
#                '2021-12-31 10:10:00', '2022-12-31 10:10:00',
#                '2023-12-31 10:10:00', '2024-12-31 10:10:00',
#                '2025-12-31 10:10:00', '2026-12-31 10:10:00'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
# Hour
pd.date_range(start="2019-05-25 10:10", periods=8, freq='H')
# Out:
# DatetimeIndex(['2019-05-25 10:10:00', '2019-05-25 11:10:00',
#                '2019-05-25 12:10:00', '2019-05-25 13:10:00',
#                '2019-05-25 14:10:00', '2019-05-25 15:10:00',
#                '2019-05-25 16:10:00', '2019-05-25 17:10:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
# Minutes

pd.date_range(start="2019-05-25 10:10", periods=8, freq='min')
# pd.date_range(start="2019-05-25 10:10", periods=8, freq='T')
# Out:
# DatetimeIndex(['2019-05-25 10:10:00', '2019-05-25 10:11:00',
#                '2019-05-25 10:12:00', '2019-05-25 10:13:00',
#                '2019-05-25 10:14:00', '2019-05-25 10:15:00',
#                '2019-05-25 10:16:00', '2019-05-25 10:17:00'],
#               dtype='datetime64[ns]', freq='T')

# %%
# Seconds

pd.date_range(start="2019-05-25 10:10", periods=8, freq='10S')
# Out:
# DatetimeIndex(['2019-05-25 10:10:00', '2019-05-25 10:10:10',
#                '2019-05-25 10:10:20', '2019-05-25 10:10:30',
#                '2019-05-25 10:10:40', '2019-05-25 10:10:50',
#                '2019-05-25 10:11:00', '2019-05-25 10:11:10'],
#               dtype='datetime64[ns]', freq='10S')

# %% [markdown]
# # DataFrame
#
# Series는 1차원
#
# 2차원 데이터 처리 필요 (Excel) => DataFrame

# %%
df = pd.DataFrame([[10, 20, 30], [40, 50, 60], [70, 80, 90]])
df
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60
# 2  70  80  90

# %%
type(df)
#판다스는 거의 데이터 프레임 구조를 쓴대
# Out:
# pandas.core.frame.DataFrame

# %%
np_array = np.arange(10,100,10).reshape(3,3)
df1 = pd.DataFrame(np_array)
df1
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60
# 2  70  80  90

# %% [markdown]
# # index와 column

# %%
# index 지정
df1.index = pd.date_range('2019-05-05',periods=3)
df1
# Out:
#              0   1   2
# 2019-05-05  10  20  30
# 2019-05-06  40  50  60
# 2019-05-07  70  80  90

# %%
df1.index
# Out:
# DatetimeIndex(['2019-05-05', '2019-05-06', '2019-05-07'], dtype='datetime64[ns]', freq='D')

# %%
# column 지정 ####
df1.columns = ['A', 'B', 'C']
df1
# Out:
#              A   B   C
# 2019-05-05  10  20  30
# 2019-05-06  40  50  60
# 2019-05-07  70  80  90

# %%
# 초기화시 인자로 전달 가능
df2 = pd.DataFrame(np.arange(10, 100, 10).reshape(3,3), 
                  index=pd.date_range('2019-03-05', periods=3, freq='M'), 
                  columns=['A', 'B', 'C'])
df2
# Out:
#              A   B   C
# 2019-03-31  10  20  30
# 2019-04-30  40  50  60
# 2019-05-31  70  80  90

# %% [markdown]
# # 딕셔너리로 DataFrame 만들기

# %%
table_data = {'연도':list(range(2010, 2020)),
              '매출액': [v**2 for i, v in enumerate(range(1,11))],
              '종업원 수': list(range(2, 30, 3))}


df = pd.DataFrame(table_data)
df
# Out:
#      연도  매출액  종업원 수
# 0  2010    1      2
# 1  2011    4      5
# 2  2012    9      8
# 3  2013   16     11
# 4  2014   25     14
# 5  2015   36     17
# 6  2016   49     20
# 7  2017   64     23
# 8  2018   81     26
# 9  2019  100     29

# %% [markdown]
# # Head & tail
# 데이터가 잘 들어갔는가 확인할 때 쓴다.

# %%
df.head()
# Out:
#      연도  매출액  종업원 수
# 0  2010    1      2
# 1  2011    4      5
# 2  2012    9      8
# 3  2013   16     11
# 4  2014   25     14

# %%
df.head(3)
# Out:
#      연도  매출액  종업원 수
# 0  2010    1      2
# 1  2011    4      5
# 2  2012    9      8

# %%
df.tail()
# Out:
#      연도  매출액  종업원 수
# 5  2015   36     17
# 6  2016   49     20
# 7  2017   64     23
# 8  2018   81     26
# 9  2019  100     29

# %%
df.tail(3)
# Out:
#      연도  매출액  종업원 수
# 7  2017   64     23
# 8  2018   81     26
# 9  2019  100     29

# %% [markdown]
# # index, columns, values

# %%
df
# Out:
#      연도  매출액  종업원 수
# 0  2010    1      2
# 1  2011    4      5
# 2  2012    9      8
# 3  2013   16     11
# 4  2014   25     14
# 5  2015   36     17
# 6  2016   49     20
# 7  2017   64     23
# 8  2018   81     26
# 9  2019  100     29

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.columns
# Out:
# Index(['연도', '매출액', '종업원 수'], dtype='object')

# %%
df.values
# Out:
# array([[2010,    1,    2],
#        [2011,    4,    5],
#        [2012,    9,    8],
#        [2013,   16,   11],
#        [2014,   25,   14],
#        [2015,   36,   17],
#        [2016,   49,   20],
#        [2017,   64,   23],
#        [2018,   81,   26],
#        [2019,  100,   29]], dtype=int64)

# %% [markdown]
# # 데이터 연산

# %%
table_data1 = {
    'A': np.arange(1, 6),
    'B': np.arange(10, 60, 10),
    'C': np.arange(100, 600, 100),
}
df1 = pd.DataFrame(table_data1)
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
table_data2 = {
    'A': [6, 7, 8],
    'B': [60, 70, 80],
    'C': [600, 700, 800],
}
df2 = pd.DataFrame(table_data2)
df2
# Out:
#    A   B    C
# 0  6  60  600
# 1  7  70  700
# 2  8  80  800

# %%
# 덧셈
df1+df2

#NaN값 주의,뺄셈, 곱,나눔 다 마찬가지
# Out:
#       A      B       C
# 0   7.0   70.0   700.0
# 1   9.0   90.0   900.0
# 2  11.0  110.0  1100.0
# 3   NaN    NaN     NaN
# 4   NaN    NaN     NaN

# %% [markdown]
# # 통계분석을 위한 method

# %%
df1 = pd.DataFrame({'봄': [256.5, 264.3, 215.9, 223.2, 312.8],
                    '여름': [770.6, 567.5, 599.8, 387.1, 446.2],
                    '가을': [363.5, 231.2, 293.1, 247.7, 381.6],
                    '겨울': [139.3, 59.9, 76.9, 109.1, 108.1]},
                    index=['2012', '2013', '2014', '2015', '2016'])
df1
# Out:
#           봄     여름     가을     겨울
# 2012  256.5  770.6  363.5  139.3
# 2013  264.3  567.5  231.2   59.9
# 2014  215.9  599.8  293.1   76.9
# 2015  223.2  387.1  247.7  109.1
# 2016  312.8  446.2  381.6  108.1

# %%
##sum / mean
df1.sum()
# Out:
# 봄     1272.7
# 여름    2771.2
# 가을    1517.1
# 겨울     493.3
# dtype: float64

# %%
#axis: 가로연산/세로연산 나타내는 축 의미(1로 주면 가로, 0이면 세로)
df1.sum(axis=1)
# Out:
# 2012    1529.9
# 2013    1122.9
# 2014    1185.7
# 2015     967.1
# 2016    1248.7
# dtype: float64

# %%
df1.mean()
# Out:
# 봄     254.54
# 여름    554.24
# 가을    303.42
# 겨울     98.66
# dtype: float64

# %%
df1.mean(axis=1)
# Out:
# 2012    382.475
# 2013    280.725
# 2014    296.425
# 2015    241.775
# 2016    312.175
# dtype: float64

# %% [markdown]
# # min / max / std / var
# 데이터 전처리할때 이런거 이용할 수 있음!

# %%
df1.min()
# Out:
# 봄     215.9
# 여름    387.1
# 가을    231.2
# 겨울     59.9
# dtype: float64

# %%
df1.min(axis=1)
# Out:
# 2012    139.3
# 2013     59.9
# 2014     76.9
# 2015    109.1
# 2016    108.1
# dtype: float64

# %%
df1.max()
# Out:
# 봄     312.8
# 여름    770.6
# 가을    381.6
# 겨울    139.3
# dtype: float64

# %%
df1.max(axis=1)
# Out:
# 2012    770.6
# 2013    567.5
# 2014    599.8
# 2015    387.1
# 2016    446.2
# dtype: float64

# %%
df1.std()
# Out:
# 봄      38.628267
# 여름    148.888895
# 가을     67.358496
# 겨울     30.925523
# dtype: float64

# %%
df1.std(axis=1)
# Out:
# 2012    274.472128
# 2013    211.128782
# 2014    221.150739
# 2015    114.166760
# 2016    146.548658
# dtype: float64

# %%
df1.var()
# Out:
# 봄      1492.143
# 여름    22167.903
# 가을     4537.167
# 겨울      956.388
# dtype: float64

# %%
df1.var(axis=1)
# Out:
# 2012    75334.949167
# 2013    44575.362500
# 2014    48907.649167
# 2015    13034.049167
# 2016    21476.509167
# dtype: float64

# %%
cumsum / cumprod
#누적합, 누적곱

# %% [markdown]
# # describe(), Info()

# %%
df1.describe()
# Out:
#                 봄          여름          가을          겨울
# count    5.000000    5.000000    5.000000    5.000000
# mean   254.540000  554.240000  303.420000   98.660000
# std     38.628267  148.888895   67.358496   30.925523
# min    215.900000  387.100000  231.200000   59.900000
# 25%    223.200000  446.200000  247.700000   76.900000
# 50%    256.500000  567.500000  293.100000  108.100000
# 75%    264.300000  599.800000  363.500000  109.100000
# max    312.800000  770.600000  381.600000  139.300000

# %%
df.info() #누락치 확인할때 좋음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
# 연도       10 non-null int64
# 매출액      10 non-null int64
# 종업원 수    10 non-null int64
# dtypes: int64(3)
# memory usage: 320.0 bytes

# %% [markdown]
# # 인덱싱, 슬라이싱

# %%
df1
# Out:
#           봄     여름     가을     겨울
# 2012  256.5  770.6  363.5  139.3
# 2013  264.3  567.5  231.2   59.9
# 2014  215.9  599.8  293.1   76.9
# 2015  223.2  387.1  247.7  109.1
# 2016  312.8  446.2  381.6  108.1

# %%
#Column으로 접근

df1['봄']
# Out:
# 2012    256.5
# 2013    264.3
# 2014    215.9
# 2015    223.2
# 2016    312.8
# Name: 봄, dtype: float64

# %%
#Row로 접근

df1[1:3]
# Out:
#           봄     여름     가을    겨울
# 2013  264.3  567.5  231.2  59.9
# 2014  215.9  599.8  293.1  76.9

# %%
df1[:2]
#index 기준으로도 할 수 있다.
# Out:
#           봄     여름     가을     겨울
# 2012  256.5  770.6  363.5  139.3
# 2013  264.3  567.5  231.2   59.9

# %%
df1.loc['2013']
#가장 정확하다., loc 쓰면 comma로 접근할 수 있따.
# Out:
# 봄     264.3
# 여름    567.5
# 가을    231.2
# 겨울     59.9
# Name: 2013, dtype: float64

# %%
df1.loc['2013':'2016']
# Out:
#           봄     여름     가을     겨울
# 2013  264.3  567.5  231.2   59.9
# 2014  215.9  599.8  293.1   76.9
# 2015  223.2  387.1  247.7  109.1
# 2016  312.8  446.2  381.6  108.1

# %% [markdown]
# # 결합

# %%
#처음에는 colum, then index
df1['봄'][:3]
# Out:
# 2012    256.5
# 2013    264.3
# 2014    215.9
# Name: 봄, dtype: float64

# %%
df1['여름'][:'2014']
# Out:
# 2012    770.6
# 2013    567.5
# 2014    599.8
# Name: 여름, dtype: float64

# %%
df1['여름'][:'2014']
#loc 쓰면 comma로 접근할 수 있따.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '여름'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-b55a3853e173> in <module>
# ----> 1 df1['여름'][:'2014']
#       2 #loc 쓰면 comma로 접근할 수 있따.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '여름'

# %% [markdown]
# # 데이터프레임 전치

# %%
df1
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      98
# 3     100     100

# %%
df1.T
#전치!
# Out:
#          0   1   2    3
# Class1  95  92  98  100
# Class2  91  93  98  100

# %% [markdown]
# # 열 순서 변경/ 행 변경

# %%
df1
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      98
# 3     100     100

# %%
df1[['겨울', '봄', '여름', '가을']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-0c2673a3bc18> in <module>
# ----> 1 df1[['겨울', '봄', '여름', '가을']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['겨울', '봄', '여름', '가을'], dtype='object')] are in the [columns]"

# %%
df1.loc[['2016', '2015', '2014']]
#순서 바꾸는데 리스트 인덱싱으로 가져온다
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-45898e8d4249> in <module>
# ----> 1 df1.loc[['2016', '2015', '2014']]
#       2 #순서 바꾸는데 리스트 인덱싱으로 가져온다
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['2016', '2015', '2014'], dtype='object')] are in the [index]"

# %%
df2 = pd.DataFrame({
    '봄': [302.9, 256.9],
    '여름': [692.6, 1053.6],
    '가을': [307.6, 225.5],
    '겨울': [98.7, 45.6]},
    index=[2010,2011]
)
df2
# Out:
#           봄      여름     가을    겨울
# 2010  302.9   692.6  307.6  98.7
# 2011  256.9  1053.6  225.5  45.6

# %% [markdown]
# # 데이터 통합(추가)하기

# %%
df1 = pd.DataFrame({'Class1': [95, 92, 98, 100],
                    'Class2': [91, 93, 98, 100]})
df1
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      98
# 3     100     100

# %%
df2 = pd.DataFrame({'Class1': [76, 88],
                    'Class2': [100, 100]})
df2
# Out:
#    Class1  Class2
# 0      76     100
# 1      88     100

# %%
df1.append(df2)
#어펜드로 같은 collum끼리 추가... 세로방향 통합
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      98
# 3     100     100
# 0      76     100
# 1      88     100

# %%
# index 무시
df1.append(df2, ignore_index=True)
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      98
# 3     100     100
# 4      76     100
# 5      88     100

# %%
#컬럼이 다 다를때

df3 = pd.DataFrame({'Class1': [80,10], 'Class3': [50, 60]})
df3
# Out:
#    Class1  Class3
# 0      80      50
# 1      10      60

# %%
df1.append(df3, ignore_index=True, sort=True)
# Out:
#    Class1  Class2  Class3
# 0      95    91.0     NaN
# 1      92    93.0     NaN
# 2      98    98.0     NaN
# 3     100   100.0     NaN
# 4      80     NaN    50.0
# 5      10     NaN    60.0

# %% [markdown]
# ## 가로방향 통합하기

# %%
df1
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      98
# 3     100     100

# %%
df4 = pd.DataFrame({'Class3': [92,93,94,91,99]})
df4
# Out:
#    Class3
# 0      92
# 1      93
# 2      94
# 3      91
# 4      99

# %%
#옆으로 컬럼을 이어붙이는거__by how = 'outer' 아니면  'inner', 'right/left~~'
df1.join(df4)
# Out:
#    Class1  Class2  Class3
# 0      95      91      92
# 1      92      93      93
# 2      98      98      94
# 3     100     100      91

# %%
###index 지정시

# %%
df1
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      98
# 3     100     100

# %% [markdown]
# # 특정 열을 기준으로 통합하기

# %%
import random
month_list = [str(i)+'월' for i in range(1,5)]

prod_A, prod_B, prod_C, prod_D = [np.random.randint(50, 100, size=4) for i in range(4)]


df_A_B = pd.DataFrame({'판매월': month_list, 
                       '제품A': prod_A,
                       '제품B': prod_B})
df_A_B
# Out:
#   판매월  제품A  제품B
# 0  1월   88   72
# 1  2월   68   80
# 2  3월   80   64
# 3  4월   66   53

# %%
df_C_D = pd.DataFrame({'판매월': month_list,
                       '제품C': prod_C,
                       '제품D': prod_D})
df_C_D
# Out:
#   판매월  제품C  제품D
# 0  1월   91   51
# 1  2월   99   56
# 2  3월   53   58
# 3  4월   64   85

# %% [markdown]
# ## merge¶
#
#
# ##조건에 따라 두개 자동을 합쳐짐

# %%
df_A_B.merge(df_C_D)
# Out:
#   판매월  제품A  제품B  제품C  제품D
# 0  1월   88   72   91   51
# 1  2월   68   80   99   56
# 2  3월   80   64   53   58
# 3  4월   66   53   64   85

# %% [markdown]
# ## mefge - how

# %%
prod_E, prod_F = [np.random.randint(50, 100, size=4) for i in range(2)]
df_E_F = pd.DataFrame({'판매월': ['3월', '4월', '5월', '6월'],
                       '제품E': prod_E,
                       '제품F': prod_F})
df_E_F
# Out:
#   판매월  제품E  제품F
# 0  3월   64   74
# 1  4월   92   63
# 2  5월   95   62
# 3  6월   65   72

# %%
df_A_B.merge(df_E_F, how='left')
#NaN값 주의
# Out:
#   판매월  제품A  제품B   제품E   제품F
# 0  1월   88   72   NaN   NaN
# 1  2월   68   80   NaN   NaN
# 2  3월   80   64  64.0  74.0
# 3  4월   66   53  92.0  63.0

# %%
df_A_B.merge(df_E_F, how='right')
# Out:
#   판매월   제품A   제품B  제품E  제품F
# 0  3월  80.0  64.0   64   74
# 1  4월  66.0  53.0   92   63
# 2  5월   NaN   NaN   95   62
# 3  6월   NaN   NaN   65   72

# %%
df_A_B.merge(df_E_F, how='inner')
# Out:
#   판매월  제품A  제품B  제품E  제품F
# 0  3월   80   64   64   74
# 1  4월   66   53   92   63

# %%
df_A_B.merge(df_E_F, how='outer')
# Out:
#   판매월   제품A   제품B   제품E   제품F
# 0  1월  88.0  72.0   NaN   NaN
# 1  2월  68.0  80.0   NaN   NaN
# 2  3월  80.0  64.0  64.0  74.0
# 3  4월  66.0  53.0  92.0  63.0
# 4  5월   NaN   NaN  95.0  62.0
# 5  6월   NaN   NaN  65.0  72.0

# %%
df_A_B.merge(df_E_F, how='outer', on="판매월")
#어떤 열을 기준으로 정렬을 할 것인가에 대한것
# Out:
#   판매월   제품A   제품B   제품E   제품F
# 0  1월  88.0  72.0   NaN   NaN
# 1  2월  68.0  80.0   NaN   NaN
# 2  3월  80.0  64.0  64.0  74.0
# 3  4월  66.0  53.0  92.0  63.0
# 4  5월   NaN   NaN  95.0  62.0
# 5  6월   NaN   NaN  65.0  72.0

# %%
#df_A_B.join(df_E_F)
이것도 같은 방법으로 쓸 수 있다.

# %% [markdown]
# # 데이터 파일 읽고 쓰기

# %% [markdown]
# ## CSV 파일

# %%
import os
BASE_DIR = os.getcwd()
DATASET_PATH = os.path.join(BASE_DIR, "201904")
print(DATASET_PATH)
# Out:
# C:\Users\student\study\201904

# %%
df = pd.read_csv(os.path.join(DATASET_PATH, '2019-04-01.csv'),  encoding = 'utf-8', error_bad_lines=False, header=None )

#utf-8: 한글파일이 잘 깨지니깐(한자같은거) 이걸 방지해주는 한글전용 읽쓰 파일   -> 기본 ansi (ex- 엑셀)에서 이걸로
#파일 행렬이 맞지 않는 경우가 있으니까 이걸 방지해주기위해 error_vad_lines~~
# Out:
# b'Skipping line 36560: expected 8 fields, saw 11\n'

# %%
  ### df = pd.read_csv('C:/Users/student/study/datasets/201904/2019-04-01.csv', encoding = 'utf-8', error_bad_lines=False)

# %%
df
# Out:
#                  0           1        2      3  \
# 0       2019-04-01  2142932948  C011020   남자상의
# 1       2019-04-01  1812194343  C013020    티셔츠
# 2       2019-04-01   954865871  C014010    아동복
# 3       2019-04-01   853175004  A021010     커피
# 4       2019-04-01   826899644  A019050     간장
# 5       2019-04-01  1095655438  L012010    면도기
# 6       2019-04-01   912133680  C011050   남자내의
# 7       2019-04-01   176168123  C013010     점퍼
# 8       2019-04-01   342609665  C011040   남자하의
# 9       2019-04-01   928928755  C021030    운동화
# 10      2019-04-01   814924610  E061100  습기제거제
# 11      2019-04-01  1983249606  C013020    티셔츠
# 12      2019-04-01   878389843  C012010   여자외의
# 13      2019-04-01  1126405207  C011040   남자하의
# 14      2019-04-01  1549553626  E061100  습기제거제
# 15      2019-04-01  1904504950  A017300     미역
# 16      2019-04-01  1073659289  C013010     점퍼
# 17      2019-04-01  1152942597  C014010    아동복
# 18      2019-04-01   943429570  C011020   남자상의
# 19      2019-04-01   420987991  A016160  과일가공품
# 20      2019-04-01  1651601070  C012020    원피스
# 21      2019-04-01  1066134397  C012010   여자외의
# 22      2019-04-01  1543762550  C014010    아동복
# 23      2019-04-01  1773531765  C013010     점퍼
# 24      2019-04-01   277908766  A019090     카레
# 25      2019-04-01     4343006  C013020    티셔츠
# 26      2019-04-01  1816679970  C012010   여자외의
# 27      2019-04-01   930687441  C011040   남자하의
# 28      2019-04-01  1919980648  I053050    필기구
# 29      2019-04-01  1025273168  A019180   즉석식품
# ...            ...         ...      ...    ...
# 208717  2019-04-01   158987580  A021010     커피
# 208718  2019-04-01  1724372429  C011020   남자상의
# 208719  2019-04-01  1541402005  C011010   남자외의
# 208720  2019-04-01   733065997  C011020   남자상의
# 208721  2019-04-01   949238026  A011080    밀가루
# 208722  2019-04-01  1567838613  C012020    원피스
# 208723  2019-04-01  1080114904  C013040    청바지
# 208724  2019-04-01   644482544  A019110    드레싱
# 208725  2019-04-01  1061108876  E061010   세탁세제
# 208726  2019-04-01   881440176  C011050   남자내의
# 208727  2019-04-01   964550396  L012030     칫솔
# 208728  2019-04-01  1611801746  C013020    티셔츠
# 208729  2019-04-01   542606987  C013010     점퍼
# 208730  2019-04-01  1529515068  C014010    아동복
# 208731  2019-04-01  1713538519  C013020    티셔츠
# 208732  2019-04-01   842901217  C013010     점퍼
# 208733  2019-04-01  1505483110  C011040   남자하의
# 208734  2019-04-01    15890860  C021020     구두
# 208735  2019-04-01  1274107683  C012010   여자외의
# 208736  2019-04-01  1447411239  C013010     점퍼
# 208737  2019-04-01  1926337210  C013010     점퍼
# 208738  2019-04-01   437201269  A011110     당면
# 208739  2019-04-01  1644781043  C013020    티셔츠
# 208740  2019-04-01  1778713139  C011020   남자상의
# 208741  2019-04-01  1573253623  C013010     점퍼
# 208742  2019-04-01   778439602  C013010     점퍼
# 208743  2019-04-01   707149138  C014010    아동복
# 208744  2019-04-01  1025782371  A022050   탄산음료
# 208745  2019-04-01   101608900  C011040   남자하의
# 208746  2019-04-01   929003352  C013010     점퍼
#
#                                                         4       5        6  \
# 0       (사이즈 : RFCB2021 shirts 110) 슬림핏)링클프리 고급모달 블루 반...   44540      NaN
# 1                          폴햄 공용슬럽브이넥반팔티셔츠(차콜) PHZ2TR3840    9900      NaN
# 2                             프렌치캣Q92DKJ040 연보라 프릴 바람막이JP   76000      NaN
# 3       [맥널티] 아이브루 케냐AA 30T+10T 인스턴트커피믹스 원두커피 케냐AA 인스턴...   16260      NaN
# 4       채선해 어간장 세트1(대멸치350g+어간장650ml) 어간장선물세트 실속선물세트 직...   37970      NaN
# 5        도루코페이스6면도날-4P SX-A1040 면도 얼굴면도기 도루코 도루코면도기 미용면도기   20450      NaN
# 6                       Dossy 남성 드로즈 빅사이즈 110 120 남성드로즈팬티   16700      NaN
# 7                                   씨저스 퀼팅점퍼 1F2-1JE01-24  143000      NaN
# 8                                     스키니핏팬츠_1X511EP706NA    9900      NaN
# 9                             투벨크로 아동단화 운동화 아동화 아동운동화 어린이   27700      NaN
# 10                          [F] 첼로제습제 20g 10개 - 데시칸-B 친환경    2400   2280.0
# 11                  네이비 로고배색 면혼방 반팔카라티셔츠 HZTS9B003N2/ 헤지스  129000      NaN
# 12                          케네스레이디 체크소매배색트렌치코트 EWTCJB0200  269000      NaN
# 13                                 랜더스 바람막이 자켓(JK125) 코발트   29300      NaN
# 14                         홈트너 옷장용제습제(120g) 습기제거제 제습제 10개   15210      NaN
# 15                      (2)미역(자른 차오름 1KG 국산)X5개/건미역 미역 말린  114520      NaN
# 16            [써스데이아일랜드]배색 프린트 소매 숏 점퍼 (T194MJP232W)(경기점)  249000      NaN
# 17                            프렌치캣 Q92DCJ070 WH프릴 스카시 C.D   63000      NaN
# 18                     [JEEP]남여공용 소매 배색 7부 티셔츠(JH2TSU064)   18000      NaN
# 19                             [홈플러스]simplus_냉동체리칠레산_500G    5990      NaN
# 20                       로즈민소매원피스 1025139 DRESS 쉬폰 레이스원피스   93370      NaN
# 21         [르오트] (TV홈쇼핑방송/무료배송) 쿨링시크 냉감 밴딩 팬츠-사이즈 55∼88다양    5900      NaN
# 22                         [ 빈 ] BT21TS05GN남아 포켓배색 그린 티셔츠   48000      NaN
# 23                            [올리비아하슬러]OH8MJP104 네크 셔링 점퍼   79900      NaN
# 24      [청정원] 병아리콩 빈달루 커리소스 360g 빈달루카레소스 병커리 인도식커리 커리소...   18170      NaN
# 25                       [반에이크]루즈핏 후드 티셔츠(VA94TSQ349Z_DG)   39800      NaN
# 26                               SOUP 벨트 숏 트렌치 코트 SV4BB90   87000      NaN
# 27                                   지오다노 슬림핏 치노팬츠 117922   15000      NaN
# 28                            [바보사랑]쿠츠와 제트스트림3 푸마 3색펜 0.5    9000   9000.0
# 29                                            두마리후라이드반반치킨   14990  14990.0
# ...                                                   ...     ...      ...
# 208717  이디야커피 원두 바이올렛200g 1갑5개 이디야커피원두 선물용원두 원두바이올렛 이디...   79310      NaN
# 208718           듀퐁 셔츠 가로스트라이프 비즈니스 긴소매 셔츠SD9SM11LS166SBU   89000      NaN
# 208719                     폴햄베스트 남성 크루넥 니트 베스트 PHY4ER1320   19900      NaN
# 208720                   [플라스틱아일랜드] 원포켓 반오픈 셔츠 (PK7WB131)   44100      NaN
# 208721                       [CJ직배송] 찰밀가루2.5kg x 6개 (총6개)   21900  21900.0
# 208722                        스크레치 포인트로 빈티지한 스타일의 청멜빵롱원피스   40000      NaN
# 208723  (사이즈 : 34) JDP-92 고양이수염 흑청 데님 데일리청바지 남성청바지 남성데...   28100      NaN
# 208724  업소용식자재 야채샐러드드레싱 3.2Kg 4EA 샐러드드레싱 업소용샐러드소스 대용량샐...   77790      NaN
# 208725                               (4가지향)컨센서스 세제 20L 말통   28100  28100.0
# 208726  (BYC)남성 스포츠 아웃밴드 3매입 드로즈(R6810) /(연관어) BYC 남성팬...   57200      NaN
# 208727                     /미소랑칫솔 어린이-0388 어린이칫솔 아동용칫솔 어린    2230      NaN
# 208728                                     슈퍼라글란티셔츠 [쁘띠뮤]    9900      NaN
# 208729  (디자인 : S11 | 사이즈 : L) 윈터 카모 솔져 점퍼 (14 color) 단...   96610      NaN
# 208730                              프렌치캣 화이트가디건 Q82DKJ080   31000      NaN
# 208731                           탑걸 롱롱롱한 언발티셔츠 TJB4TS700F   59000      NaN
# 208732                보아털탈부착 아웃포켓 누빔야상점퍼GJA1PD601F/ 지지피엑스   75000      NaN
# 208733                                 세븐퍼센트x디즈니 반바지 신발미키   25000      NaN
# 208734  남성구두 M6427 천연가죽 4cm 심플남성화 신사화 /(연관어) 천연가죽 구두 신...   78900      NaN
# 208735            [대구백화점 II관] [보브]롱벨티드핸드메이드코트(7159116103)  228000      NaN
# 208736                          [후앙스]모직소매배색 레자점퍼 PWJP1816   66800      NaN
# 208737                      [아르떼]W 아르떼 루즈핏 홑 점퍼 dkbcwm510  149000      NaN
# 208738    [CJ] CJ이츠웰당면14kg th 식당용당면 찰당면 식자재당면 업소용당면 고구마당면   63610      NaN
# 208739                 [디자인유나이티드] 스트라이프 티셔츠 7339101101099   14900      NaN
# 208740                   [예작셔츠] 반소매 일반핏 평직 솔리드 셔츠 9MBR203   30000      NaN
# 208741  골지배색집업점퍼 /(연관어) 여성의류 여성점퍼 여성아우터 겨울점퍼 집업점퍼 겨울아우...   67800      NaN
# 208742        폴햄 블럭 후드 윈드브레이크 점퍼화이트 PHZ2JJ3020 PHZ2JJ3020   59900      NaN
# 208743                      [캉골키즈]포켓 프린트 라글란 티셔츠 0703 화이트   49000      NaN
# 208744                  (강추)[코카콜라] 조지아 오리지날(업소용) 175ml(30   18400      NaN
# 208745                           티아이포맨 팬츠 M174MPT803M1BL5   44400      NaN
# 208746                 [랩][DISNEY X LAP] 미키 등판 꽃자수 스카잔 점퍼   60000      NaN
#
#             7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10     -120.0
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        0.0
# 29        0.0
# ...       ...
# 208717    NaN
# 208718    NaN
# 208719    NaN
# 208720    NaN
# 208721    0.0
# 208722    NaN
# 208723    NaN
# 208724    NaN
# 208725    0.0
# 208726    NaN
# 208727    NaN
# 208728    NaN
# 208729    NaN
# 208730    NaN
# 208731    NaN
# 208732    NaN
# 208733    NaN
# 208734    NaN
# 208735    NaN
# 208736    NaN
# 208737    NaN
# 208738    NaN
# 208739    NaN
# 208740    NaN
# 208741    NaN
# 208742    NaN
# 208743    NaN
# 208744    NaN
# 208745    NaN
# 208746    NaN
#
# [208747 rows x 8 columns]

# %%
df.columns = ['수집일자', '상품ID','품목ID', '품목명', '상품명','판매가격', '할인가격','혜택가격']

# %%
df
# Out:
#               수집일자        상품ID     품목ID    품목명  \
# 0       2019-04-01  2142932948  C011020   남자상의
# 1       2019-04-01  1812194343  C013020    티셔츠
# 2       2019-04-01   954865871  C014010    아동복
# 3       2019-04-01   853175004  A021010     커피
# 4       2019-04-01   826899644  A019050     간장
# 5       2019-04-01  1095655438  L012010    면도기
# 6       2019-04-01   912133680  C011050   남자내의
# 7       2019-04-01   176168123  C013010     점퍼
# 8       2019-04-01   342609665  C011040   남자하의
# 9       2019-04-01   928928755  C021030    운동화
# 10      2019-04-01   814924610  E061100  습기제거제
# 11      2019-04-01  1983249606  C013020    티셔츠
# 12      2019-04-01   878389843  C012010   여자외의
# 13      2019-04-01  1126405207  C011040   남자하의
# 14      2019-04-01  1549553626  E061100  습기제거제
# 15      2019-04-01  1904504950  A017300     미역
# 16      2019-04-01  1073659289  C013010     점퍼
# 17      2019-04-01  1152942597  C014010    아동복
# 18      2019-04-01   943429570  C011020   남자상의
# 19      2019-04-01   420987991  A016160  과일가공품
# 20      2019-04-01  1651601070  C012020    원피스
# 21      2019-04-01  1066134397  C012010   여자외의
# 22      2019-04-01  1543762550  C014010    아동복
# 23      2019-04-01  1773531765  C013010     점퍼
# 24      2019-04-01   277908766  A019090     카레
# 25      2019-04-01     4343006  C013020    티셔츠
# 26      2019-04-01  1816679970  C012010   여자외의
# 27      2019-04-01   930687441  C011040   남자하의
# 28      2019-04-01  1919980648  I053050    필기구
# 29      2019-04-01  1025273168  A019180   즉석식품
# ...            ...         ...      ...    ...
# 208717  2019-04-01   158987580  A021010     커피
# 208718  2019-04-01  1724372429  C011020   남자상의
# 208719  2019-04-01  1541402005  C011010   남자외의
# 208720  2019-04-01   733065997  C011020   남자상의
# 208721  2019-04-01   949238026  A011080    밀가루
# 208722  2019-04-01  1567838613  C012020    원피스
# 208723  2019-04-01  1080114904  C013040    청바지
# 208724  2019-04-01   644482544  A019110    드레싱
# 208725  2019-04-01  1061108876  E061010   세탁세제
# 208726  2019-04-01   881440176  C011050   남자내의
# 208727  2019-04-01   964550396  L012030     칫솔
# 208728  2019-04-01  1611801746  C013020    티셔츠
# 208729  2019-04-01   542606987  C013010     점퍼
# 208730  2019-04-01  1529515068  C014010    아동복
# 208731  2019-04-01  1713538519  C013020    티셔츠
# 208732  2019-04-01   842901217  C013010     점퍼
# 208733  2019-04-01  1505483110  C011040   남자하의
# 208734  2019-04-01    15890860  C021020     구두
# 208735  2019-04-01  1274107683  C012010   여자외의
# 208736  2019-04-01  1447411239  C013010     점퍼
# 208737  2019-04-01  1926337210  C013010     점퍼
# 208738  2019-04-01   437201269  A011110     당면
# 208739  2019-04-01  1644781043  C013020    티셔츠
# 208740  2019-04-01  1778713139  C011020   남자상의
# 208741  2019-04-01  1573253623  C013010     점퍼
# 208742  2019-04-01   778439602  C013010     점퍼
# 208743  2019-04-01   707149138  C014010    아동복
# 208744  2019-04-01  1025782371  A022050   탄산음료
# 208745  2019-04-01   101608900  C011040   남자하의
# 208746  2019-04-01   929003352  C013010     점퍼
#
#                                                       상품명    판매가격     할인가격  \
# 0       (사이즈 : RFCB2021 shirts 110) 슬림핏)링클프리 고급모달 블루 반...   44540      NaN
# 1                          폴햄 공용슬럽브이넥반팔티셔츠(차콜) PHZ2TR3840    9900      NaN
# 2                             프렌치캣Q92DKJ040 연보라 프릴 바람막이JP   76000      NaN
# 3       [맥널티] 아이브루 케냐AA 30T+10T 인스턴트커피믹스 원두커피 케냐AA 인스턴...   16260      NaN
# 4       채선해 어간장 세트1(대멸치350g+어간장650ml) 어간장선물세트 실속선물세트 직...   37970      NaN
# 5        도루코페이스6면도날-4P SX-A1040 면도 얼굴면도기 도루코 도루코면도기 미용면도기   20450      NaN
# 6                       Dossy 남성 드로즈 빅사이즈 110 120 남성드로즈팬티   16700      NaN
# 7                                   씨저스 퀼팅점퍼 1F2-1JE01-24  143000      NaN
# 8                                     스키니핏팬츠_1X511EP706NA    9900      NaN
# 9                             투벨크로 아동단화 운동화 아동화 아동운동화 어린이   27700      NaN
# 10                          [F] 첼로제습제 20g 10개 - 데시칸-B 친환경    2400   2280.0
# 11                  네이비 로고배색 면혼방 반팔카라티셔츠 HZTS9B003N2/ 헤지스  129000      NaN
# 12                          케네스레이디 체크소매배색트렌치코트 EWTCJB0200  269000      NaN
# 13                                 랜더스 바람막이 자켓(JK125) 코발트   29300      NaN
# 14                         홈트너 옷장용제습제(120g) 습기제거제 제습제 10개   15210      NaN
# 15                      (2)미역(자른 차오름 1KG 국산)X5개/건미역 미역 말린  114520      NaN
# 16            [써스데이아일랜드]배색 프린트 소매 숏 점퍼 (T194MJP232W)(경기점)  249000      NaN
# 17                            프렌치캣 Q92DCJ070 WH프릴 스카시 C.D   63000      NaN
# 18                     [JEEP]남여공용 소매 배색 7부 티셔츠(JH2TSU064)   18000      NaN
# 19                             [홈플러스]simplus_냉동체리칠레산_500G    5990      NaN
# 20                       로즈민소매원피스 1025139 DRESS 쉬폰 레이스원피스   93370      NaN
# 21         [르오트] (TV홈쇼핑방송/무료배송) 쿨링시크 냉감 밴딩 팬츠-사이즈 55∼88다양    5900      NaN
# 22                         [ 빈 ] BT21TS05GN남아 포켓배색 그린 티셔츠   48000      NaN
# 23                            [올리비아하슬러]OH8MJP104 네크 셔링 점퍼   79900      NaN
# 24      [청정원] 병아리콩 빈달루 커리소스 360g 빈달루카레소스 병커리 인도식커리 커리소...   18170      NaN
# 25                       [반에이크]루즈핏 후드 티셔츠(VA94TSQ349Z_DG)   39800      NaN
# 26                               SOUP 벨트 숏 트렌치 코트 SV4BB90   87000      NaN
# 27                                   지오다노 슬림핏 치노팬츠 117922   15000      NaN
# 28                            [바보사랑]쿠츠와 제트스트림3 푸마 3색펜 0.5    9000   9000.0
# 29                                            두마리후라이드반반치킨   14990  14990.0
# ...                                                   ...     ...      ...
# 208717  이디야커피 원두 바이올렛200g 1갑5개 이디야커피원두 선물용원두 원두바이올렛 이디...   79310      NaN
# 208718           듀퐁 셔츠 가로스트라이프 비즈니스 긴소매 셔츠SD9SM11LS166SBU   89000      NaN
# 208719                     폴햄베스트 남성 크루넥 니트 베스트 PHY4ER1320   19900      NaN
# 208720                   [플라스틱아일랜드] 원포켓 반오픈 셔츠 (PK7WB131)   44100      NaN
# 208721                       [CJ직배송] 찰밀가루2.5kg x 6개 (총6개)   21900  21900.0
# 208722                        스크레치 포인트로 빈티지한 스타일의 청멜빵롱원피스   40000      NaN
# 208723  (사이즈 : 34) JDP-92 고양이수염 흑청 데님 데일리청바지 남성청바지 남성데...   28100      NaN
# 208724  업소용식자재 야채샐러드드레싱 3.2Kg 4EA 샐러드드레싱 업소용샐러드소스 대용량샐...   77790      NaN
# 208725                               (4가지향)컨센서스 세제 20L 말통   28100  28100.0
# 208726  (BYC)남성 스포츠 아웃밴드 3매입 드로즈(R6810) /(연관어) BYC 남성팬...   57200      NaN
# 208727                     /미소랑칫솔 어린이-0388 어린이칫솔 아동용칫솔 어린    2230      NaN
# 208728                                     슈퍼라글란티셔츠 [쁘띠뮤]    9900      NaN
# 208729  (디자인 : S11 | 사이즈 : L) 윈터 카모 솔져 점퍼 (14 color) 단...   96610      NaN
# 208730                              프렌치캣 화이트가디건 Q82DKJ080   31000      NaN
# 208731                           탑걸 롱롱롱한 언발티셔츠 TJB4TS700F   59000      NaN
# 208732                보아털탈부착 아웃포켓 누빔야상점퍼GJA1PD601F/ 지지피엑스   75000      NaN
# 208733                                 세븐퍼센트x디즈니 반바지 신발미키   25000      NaN
# 208734  남성구두 M6427 천연가죽 4cm 심플남성화 신사화 /(연관어) 천연가죽 구두 신...   78900      NaN
# 208735            [대구백화점 II관] [보브]롱벨티드핸드메이드코트(7159116103)  228000      NaN
# 208736                          [후앙스]모직소매배색 레자점퍼 PWJP1816   66800      NaN
# 208737                      [아르떼]W 아르떼 루즈핏 홑 점퍼 dkbcwm510  149000      NaN
# 208738    [CJ] CJ이츠웰당면14kg th 식당용당면 찰당면 식자재당면 업소용당면 고구마당면   63610      NaN
# 208739                 [디자인유나이티드] 스트라이프 티셔츠 7339101101099   14900      NaN
# 208740                   [예작셔츠] 반소매 일반핏 평직 솔리드 셔츠 9MBR203   30000      NaN
# 208741  골지배색집업점퍼 /(연관어) 여성의류 여성점퍼 여성아우터 겨울점퍼 집업점퍼 겨울아우...   67800      NaN
# 208742        폴햄 블럭 후드 윈드브레이크 점퍼화이트 PHZ2JJ3020 PHZ2JJ3020   59900      NaN
# 208743                      [캉골키즈]포켓 프린트 라글란 티셔츠 0703 화이트   49000      NaN
# 208744                  (강추)[코카콜라] 조지아 오리지날(업소용) 175ml(30   18400      NaN
# 208745                           티아이포맨 팬츠 M174MPT803M1BL5   44400      NaN
# 208746                 [랩][DISNEY X LAP] 미키 등판 꽃자수 스카잔 점퍼   60000      NaN
#
#          혜택가격
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10     -120.0
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        0.0
# 29        0.0
# ...       ...
# 208717    NaN
# 208718    NaN
# 208719    NaN
# 208720    NaN
# 208721    0.0
# 208722    NaN
# 208723    NaN
# 208724    NaN
# 208725    0.0
# 208726    NaN
# 208727    NaN
# 208728    NaN
# 208729    NaN
# 208730    NaN
# 208731    NaN
# 208732    NaN
# 208733    NaN
# 208734    NaN
# 208735    NaN
# 208736    NaN
# 208737    NaN
# 208738    NaN
# 208739    NaN
# 208740    NaN
# 208741    NaN
# 208742    NaN
# 208743    NaN
# 208744    NaN
# 208745    NaN
# 208746    NaN
#
# [208747 rows x 8 columns]

# %%
df.head()
# Out:
#          수집일자        상품ID     품목ID   품목명  \
# 0  2019-04-01  2142932948  C011020  남자상의
# 1  2019-04-01  1812194343  C013020   티셔츠
# 2  2019-04-01   954865871  C014010   아동복
# 3  2019-04-01   853175004  A021010    커피
# 4  2019-04-01   826899644  A019050    간장
#
#                                                  상품명   판매가격  할인가격  혜택가격
# 0  (사이즈 : RFCB2021 shirts 110) 슬림핏)링클프리 고급모달 블루 반...  44540   NaN   NaN
# 1                     폴햄 공용슬럽브이넥반팔티셔츠(차콜) PHZ2TR3840   9900   NaN   NaN
# 2                        프렌치캣Q92DKJ040 연보라 프릴 바람막이JP  76000   NaN   NaN
# 3  [맥널티] 아이브루 케냐AA 30T+10T 인스턴트커피믹스 원두커피 케냐AA 인스턴...  16260   NaN   NaN
# 4  채선해 어간장 세트1(대멸치350g+어간장650ml) 어간장선물세트 실속선물세트 직...  37970   NaN   NaN

# %%
df.describe()
# Out:
#                상품ID          판매가격          할인가격          혜택가격
# count  2.087470e+05  2.087470e+05  2.663300e+04  2.663300e+04
# mean   1.116270e+09  8.502752e+04  3.621821e+04 -9.331949e+03
# std    6.167795e+08  1.997164e+05  1.225324e+05  4.895031e+04
# min    5.739000e+03  9.000000e+01  9.000000e+01 -1.865260e+06
# 25%    6.507114e+08  2.180000e+04  7.400000e+03 -9.100000e+02
# 50%    1.087380e+09  3.983000e+04  1.690000e+04  0.000000e+00
# 75%    1.689947e+09  8.156000e+04  3.294000e+04  0.000000e+00
# max    2.147355e+09  1.060000e+07  4.768320e+06  0.000000e+00

# %%
##공공데이터 csv 파일 실습

df1 = pd.read_csv('temp.csv')
# df1 = pd.read_csv('temp.csv', encoding='utf8') # 사실상 표준 # default
# df1 = pd.read_csv('temp.csv', encoding='cp949') # windows

# %% [markdown]
# # 연습문제

# %%
import os
BASE_DIR = os.getcwd()
DATASET_PATH = os.path.join(BASE_DIR, "201904")

# %%
initial_file = os.path.join(DATASET_PATH,"2019-04-01.csv")


o_df = pd.read_csv(initial_file, header=None, error_bad_lines=False,encoding = 'utf-8')
o_df
# Out:
# b'Skipping line 36560: expected 8 fields, saw 11\n'
#                  0           1        2      3  \
# 0       2019-04-01  2142932948  C011020   남자상의
# 1       2019-04-01  1812194343  C013020    티셔츠
# 2       2019-04-01   954865871  C014010    아동복
# 3       2019-04-01   853175004  A021010     커피
# 4       2019-04-01   826899644  A019050     간장
# 5       2019-04-01  1095655438  L012010    면도기
# 6       2019-04-01   912133680  C011050   남자내의
# 7       2019-04-01   176168123  C013010     점퍼
# 8       2019-04-01   342609665  C011040   남자하의
# 9       2019-04-01   928928755  C021030    운동화
# 10      2019-04-01   814924610  E061100  습기제거제
# 11      2019-04-01  1983249606  C013020    티셔츠
# 12      2019-04-01   878389843  C012010   여자외의
# 13      2019-04-01  1126405207  C011040   남자하의
# 14      2019-04-01  1549553626  E061100  습기제거제
# 15      2019-04-01  1904504950  A017300     미역
# 16      2019-04-01  1073659289  C013010     점퍼
# 17      2019-04-01  1152942597  C014010    아동복
# 18      2019-04-01   943429570  C011020   남자상의
# 19      2019-04-01   420987991  A016160  과일가공품
# 20      2019-04-01  1651601070  C012020    원피스
# 21      2019-04-01  1066134397  C012010   여자외의
# 22      2019-04-01  1543762550  C014010    아동복
# 23      2019-04-01  1773531765  C013010     점퍼
# 24      2019-04-01   277908766  A019090     카레
# 25      2019-04-01     4343006  C013020    티셔츠
# 26      2019-04-01  1816679970  C012010   여자외의
# 27      2019-04-01   930687441  C011040   남자하의
# 28      2019-04-01  1919980648  I053050    필기구
# 29      2019-04-01  1025273168  A019180   즉석식품
# ...            ...         ...      ...    ...
# 208717  2019-04-01   158987580  A021010     커피
# 208718  2019-04-01  1724372429  C011020   남자상의
# 208719  2019-04-01  1541402005  C011010   남자외의
# 208720  2019-04-01   733065997  C011020   남자상의
# 208721  2019-04-01   949238026  A011080    밀가루
# 208722  2019-04-01  1567838613  C012020    원피스
# 208723  2019-04-01  1080114904  C013040    청바지
# 208724  2019-04-01   644482544  A019110    드레싱
# 208725  2019-04-01  1061108876  E061010   세탁세제
# 208726  2019-04-01   881440176  C011050   남자내의
# 208727  2019-04-01   964550396  L012030     칫솔
# 208728  2019-04-01  1611801746  C013020    티셔츠
# 208729  2019-04-01   542606987  C013010     점퍼
# 208730  2019-04-01  1529515068  C014010    아동복
# 208731  2019-04-01  1713538519  C013020    티셔츠
# 208732  2019-04-01   842901217  C013010     점퍼
# 208733  2019-04-01  1505483110  C011040   남자하의
# 208734  2019-04-01    15890860  C021020     구두
# 208735  2019-04-01  1274107683  C012010   여자외의
# 208736  2019-04-01  1447411239  C013010     점퍼
# 208737  2019-04-01  1926337210  C013010     점퍼
# 208738  2019-04-01   437201269  A011110     당면
# 208739  2019-04-01  1644781043  C013020    티셔츠
# 208740  2019-04-01  1778713139  C011020   남자상의
# 208741  2019-04-01  1573253623  C013010     점퍼
# 208742  2019-04-01   778439602  C013010     점퍼
# 208743  2019-04-01   707149138  C014010    아동복
# 208744  2019-04-01  1025782371  A022050   탄산음료
# 208745  2019-04-01   101608900  C011040   남자하의
# 208746  2019-04-01   929003352  C013010     점퍼
#
#                                                         4       5        6  \
# 0       (사이즈 : RFCB2021 shirts 110) 슬림핏)링클프리 고급모달 블루 반...   44540      NaN
# 1                          폴햄 공용슬럽브이넥반팔티셔츠(차콜) PHZ2TR3840    9900      NaN
# 2                             프렌치캣Q92DKJ040 연보라 프릴 바람막이JP   76000      NaN
# 3       [맥널티] 아이브루 케냐AA 30T+10T 인스턴트커피믹스 원두커피 케냐AA 인스턴...   16260      NaN
# 4       채선해 어간장 세트1(대멸치350g+어간장650ml) 어간장선물세트 실속선물세트 직...   37970      NaN
# 5        도루코페이스6면도날-4P SX-A1040 면도 얼굴면도기 도루코 도루코면도기 미용면도기   20450      NaN
# 6                       Dossy 남성 드로즈 빅사이즈 110 120 남성드로즈팬티   16700      NaN
# 7                                   씨저스 퀼팅점퍼 1F2-1JE01-24  143000      NaN
# 8                                     스키니핏팬츠_1X511EP706NA    9900      NaN
# 9                             투벨크로 아동단화 운동화 아동화 아동운동화 어린이   27700      NaN
# 10                          [F] 첼로제습제 20g 10개 - 데시칸-B 친환경    2400   2280.0
# 11                  네이비 로고배색 면혼방 반팔카라티셔츠 HZTS9B003N2/ 헤지스  129000      NaN
# 12                          케네스레이디 체크소매배색트렌치코트 EWTCJB0200  269000      NaN
# 13                                 랜더스 바람막이 자켓(JK125) 코발트   29300      NaN
# 14                         홈트너 옷장용제습제(120g) 습기제거제 제습제 10개   15210      NaN
# 15                      (2)미역(자른 차오름 1KG 국산)X5개/건미역 미역 말린  114520      NaN
# 16            [써스데이아일랜드]배색 프린트 소매 숏 점퍼 (T194MJP232W)(경기점)  249000      NaN
# 17                            프렌치캣 Q92DCJ070 WH프릴 스카시 C.D   63000      NaN
# 18                     [JEEP]남여공용 소매 배색 7부 티셔츠(JH2TSU064)   18000      NaN
# 19                             [홈플러스]simplus_냉동체리칠레산_500G    5990      NaN
# 20                       로즈민소매원피스 1025139 DRESS 쉬폰 레이스원피스   93370      NaN
# 21         [르오트] (TV홈쇼핑방송/무료배송) 쿨링시크 냉감 밴딩 팬츠-사이즈 55∼88다양    5900      NaN
# 22                         [ 빈 ] BT21TS05GN남아 포켓배색 그린 티셔츠   48000      NaN
# 23                            [올리비아하슬러]OH8MJP104 네크 셔링 점퍼   79900      NaN
# 24      [청정원] 병아리콩 빈달루 커리소스 360g 빈달루카레소스 병커리 인도식커리 커리소...   18170      NaN
# 25                       [반에이크]루즈핏 후드 티셔츠(VA94TSQ349Z_DG)   39800      NaN
# 26                               SOUP 벨트 숏 트렌치 코트 SV4BB90   87000      NaN
# 27                                   지오다노 슬림핏 치노팬츠 117922   15000      NaN
# 28                            [바보사랑]쿠츠와 제트스트림3 푸마 3색펜 0.5    9000   9000.0
# 29                                            두마리후라이드반반치킨   14990  14990.0
# ...                                                   ...     ...      ...
# 208717  이디야커피 원두 바이올렛200g 1갑5개 이디야커피원두 선물용원두 원두바이올렛 이디...   79310      NaN
# 208718           듀퐁 셔츠 가로스트라이프 비즈니스 긴소매 셔츠SD9SM11LS166SBU   89000      NaN
# 208719                     폴햄베스트 남성 크루넥 니트 베스트 PHY4ER1320   19900      NaN
# 208720                   [플라스틱아일랜드] 원포켓 반오픈 셔츠 (PK7WB131)   44100      NaN
# 208721                       [CJ직배송] 찰밀가루2.5kg x 6개 (총6개)   21900  21900.0
# 208722                        스크레치 포인트로 빈티지한 스타일의 청멜빵롱원피스   40000      NaN
# 208723  (사이즈 : 34) JDP-92 고양이수염 흑청 데님 데일리청바지 남성청바지 남성데...   28100      NaN
# 208724  업소용식자재 야채샐러드드레싱 3.2Kg 4EA 샐러드드레싱 업소용샐러드소스 대용량샐...   77790      NaN
# 208725                               (4가지향)컨센서스 세제 20L 말통   28100  28100.0
# 208726  (BYC)남성 스포츠 아웃밴드 3매입 드로즈(R6810) /(연관어) BYC 남성팬...   57200      NaN
# 208727                     /미소랑칫솔 어린이-0388 어린이칫솔 아동용칫솔 어린    2230      NaN
# 208728                                     슈퍼라글란티셔츠 [쁘띠뮤]    9900      NaN
# 208729  (디자인 : S11 | 사이즈 : L) 윈터 카모 솔져 점퍼 (14 color) 단...   96610      NaN
# 208730                              프렌치캣 화이트가디건 Q82DKJ080   31000      NaN
# 208731                           탑걸 롱롱롱한 언발티셔츠 TJB4TS700F   59000      NaN
# 208732                보아털탈부착 아웃포켓 누빔야상점퍼GJA1PD601F/ 지지피엑스   75000      NaN
# 208733                                 세븐퍼센트x디즈니 반바지 신발미키   25000      NaN
# 208734  남성구두 M6427 천연가죽 4cm 심플남성화 신사화 /(연관어) 천연가죽 구두 신...   78900      NaN
# 208735            [대구백화점 II관] [보브]롱벨티드핸드메이드코트(7159116103)  228000      NaN
# 208736                          [후앙스]모직소매배색 레자점퍼 PWJP1816   66800      NaN
# 208737                      [아르떼]W 아르떼 루즈핏 홑 점퍼 dkbcwm510  149000      NaN
# 208738    [CJ] CJ이츠웰당면14kg th 식당용당면 찰당면 식자재당면 업소용당면 고구마당면   63610      NaN
# 208739                 [디자인유나이티드] 스트라이프 티셔츠 7339101101099   14900      NaN
# 208740                   [예작셔츠] 반소매 일반핏 평직 솔리드 셔츠 9MBR203   30000      NaN
# 208741  골지배색집업점퍼 /(연관어) 여성의류 여성점퍼 여성아우터 겨울점퍼 집업점퍼 겨울아우...   67800      NaN
# 208742        폴햄 블럭 후드 윈드브레이크 점퍼화이트 PHZ2JJ3020 PHZ2JJ3020   59900      NaN
# 208743                      [캉골키즈]포켓 프린트 라글란 티셔츠 0703 화이트   49000      NaN
# 208744                  (강추)[코카콜라] 조지아 오리지날(업소용) 175ml(30   18400      NaN
# 208745                           티아이포맨 팬츠 M174MPT803M1BL5   44400      NaN
# 208746                 [랩][DISNEY X LAP] 미키 등판 꽃자수 스카잔 점퍼   60000      NaN
#
#             7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10     -120.0
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        0.0
# 29        0.0
# ...       ...
# 208717    NaN
# 208718    NaN
# 208719    NaN
# 208720    NaN
# 208721    0.0
# 208722    NaN
# 208723    NaN
# 208724    NaN
# 208725    0.0
# 208726    NaN
# 208727    NaN
# 208728    NaN
# 208729    NaN
# 208730    NaN
# 208731    NaN
# 208732    NaN
# 208733    NaN
# 208734    NaN
# 208735    NaN
# 208736    NaN
# 208737    NaN
# 208738    NaN
# 208739    NaN
# 208740    NaN
# 208741    NaN
# 208742    NaN
# 208743    NaN
# 208744    NaN
# 208745    NaN
# 208746    NaN
#
# [208747 rows x 8 columns]

# %%
for x in pd.date_range('2019-04-02',periods=29):
    date = x.strftime('%Y-%m-%d')
    filename="{}.csv".format(date)
    
    filepath = os.path.join(DATASET_PATH,filename)
    df = pd.read_csv(filepath, header=None, error_bad_lines=False, encoding='utf-8')
    o_df = o_df.append(df)
# Out:
# b'Skipping line 222462: expected 8 fields, saw 11\n'
# b'Skipping line 27894: expected 8 fields, saw 11\n'
# b'Skipping line 45907: expected 8 fields, saw 11\n'
# b'Skipping line 45538: expected 8 fields, saw 11\n'
# b'Skipping line 89789: expected 8 fields, saw 11\n'
# b'Skipping line 219259: expected 8 fields, saw 11\n'
# b'Skipping line 129303: expected 8 fields, saw 11\n'
# b'Skipping line 272309: expected 8 fields, saw 11\n'
# b'Skipping line 211460: expected 8 fields, saw 11\n'
# b'Skipping line 57879: expected 8 fields, saw 11\n'
# b'Skipping line 170099: expected 8 fields, saw 11\n'
# b'Skipping line 168991: expected 8 fields, saw 11\n'
# b'Skipping line 61227: expected 8 fields, saw 11\n'
# b'Skipping line 139967: expected 8 fields, saw 11\n'
# b'Skipping line 61480: expected 8 fields, saw 11\n'
# b'Skipping line 77728: expected 8 fields, saw 11\n'
# b'Skipping line 271889: expected 8 fields, saw 11\n'
# b'Skipping line 223096: expected 8 fields, saw 11\n'
# b'Skipping line 104855: expected 8 fields, saw 11\n'
# b'Skipping line 18081: expected 8 fields, saw 11\n'

# %%
o_df
# Out:
#                  0           1        2      3  \
# 0       2019-04-01  2142932948  C011020   남자상의
# 1       2019-04-01  1812194343  C013020    티셔츠
# 2       2019-04-01   954865871  C014010    아동복
# 3       2019-04-01   853175004  A021010     커피
# 4       2019-04-01   826899644  A019050     간장
# 5       2019-04-01  1095655438  L012010    면도기
# 6       2019-04-01   912133680  C011050   남자내의
# 7       2019-04-01   176168123  C013010     점퍼
# 8       2019-04-01   342609665  C011040   남자하의
# 9       2019-04-01   928928755  C021030    운동화
# 10      2019-04-01   814924610  E061100  습기제거제
# 11      2019-04-01  1983249606  C013020    티셔츠
# 12      2019-04-01   878389843  C012010   여자외의
# 13      2019-04-01  1126405207  C011040   남자하의
# 14      2019-04-01  1549553626  E061100  습기제거제
# 15      2019-04-01  1904504950  A017300     미역
# 16      2019-04-01  1073659289  C013010     점퍼
# 17      2019-04-01  1152942597  C014010    아동복
# 18      2019-04-01   943429570  C011020   남자상의
# 19      2019-04-01   420987991  A016160  과일가공품
# 20      2019-04-01  1651601070  C012020    원피스
# 21      2019-04-01  1066134397  C012010   여자외의
# 22      2019-04-01  1543762550  C014010    아동복
# 23      2019-04-01  1773531765  C013010     점퍼
# 24      2019-04-01   277908766  A019090     카레
# 25      2019-04-01     4343006  C013020    티셔츠
# 26      2019-04-01  1816679970  C012010   여자외의
# 27      2019-04-01   930687441  C011040   남자하의
# 28      2019-04-01  1919980648  I053050    필기구
# 29      2019-04-01  1025273168  A019180   즉석식품
# ...            ...         ...      ...    ...
# 298820  2019-04-30  1511051984  C013020    티셔츠
# 298821  2019-04-30  2009086191  C012010   여자외의
# 298822  2019-04-30   348004141  C012010   여자외의
# 298823  2019-04-30   539666943  C014010    아동복
# 298824  2019-04-30  1530685344  L012040     치약
# 298825  2019-04-30   979302868  C013010     점퍼
# 298826  2019-04-30  1599670444  C021020     구두
# 298827  2019-04-30   780380817  C011040   남자하의
# 298828  2019-04-30   817474478  C012010   여자외의
# 298829  2019-04-30  1123426508  C013020    티셔츠
# 298830  2019-04-30   966245842  C013020    티셔츠
# 298831  2019-04-30  1926058617  C013020    티셔츠
# 298832  2019-04-30  1995938056  C011020   남자상의
# 298833  2019-04-30  1484669859  C013010     점퍼
# 298834  2019-04-30  1779929690  C013010     점퍼
# 298835  2019-04-30  1485126001  C011020   남자상의
# 298836  2019-04-30   329101001  C014010    아동복
# 298837  2019-04-30   776844370  C012050   여자하의
# 298838  2019-04-30   921326545  C012050   여자하의
# 298839  2019-04-30  1589175955  C013010     점퍼
# 298840  2019-04-30  2006950378  C011040   남자하의
# 298841  2019-04-30  1734495884  L012060     샴푸
# 298842  2019-04-30  1927456115  A013090     전복
# 298843  2019-04-30  1029223867  C012050   여자하의
# 298844  2019-04-30  1917998337  C013020    티셔츠
# 298845  2019-04-30   815310680  C014010    아동복
# 298846  2019-04-30  1747545991  C012030   여자상의
# 298847  2019-04-30   672400750  C011020   남자상의
# 298848  2019-04-30   732785486  A019040     소금
# 298849  2019-04-30  2118547344  C013040    청바지
#
#                                                         4       5        6  \
# 0       (사이즈 : RFCB2021 shirts 110) 슬림핏)링클프리 고급모달 블루 반...   44540      NaN
# 1                          폴햄 공용슬럽브이넥반팔티셔츠(차콜) PHZ2TR3840    9900      NaN
# 2                             프렌치캣Q92DKJ040 연보라 프릴 바람막이JP   76000      NaN
# 3       [맥널티] 아이브루 케냐AA 30T+10T 인스턴트커피믹스 원두커피 케냐AA 인스턴...   16260      NaN
# 4       채선해 어간장 세트1(대멸치350g+어간장650ml) 어간장선물세트 실속선물세트 직...   37970      NaN
# 5        도루코페이스6면도날-4P SX-A1040 면도 얼굴면도기 도루코 도루코면도기 미용면도기   20450      NaN
# 6                       Dossy 남성 드로즈 빅사이즈 110 120 남성드로즈팬티   16700      NaN
# 7                                   씨저스 퀼팅점퍼 1F2-1JE01-24  143000      NaN
# 8                                     스키니핏팬츠_1X511EP706NA    9900      NaN
# 9                             투벨크로 아동단화 운동화 아동화 아동운동화 어린이   27700      NaN
# 10                          [F] 첼로제습제 20g 10개 - 데시칸-B 친환경    2400   2280.0
# 11                  네이비 로고배색 면혼방 반팔카라티셔츠 HZTS9B003N2/ 헤지스  129000      NaN
# 12                          케네스레이디 체크소매배색트렌치코트 EWTCJB0200  269000      NaN
# 13                                 랜더스 바람막이 자켓(JK125) 코발트   29300      NaN
# 14                         홈트너 옷장용제습제(120g) 습기제거제 제습제 10개   15210      NaN
# 15                      (2)미역(자른 차오름 1KG 국산)X5개/건미역 미역 말린  114520      NaN
# 16            [써스데이아일랜드]배색 프린트 소매 숏 점퍼 (T194MJP232W)(경기점)  249000      NaN
# 17                            프렌치캣 Q92DCJ070 WH프릴 스카시 C.D   63000      NaN
# 18                     [JEEP]남여공용 소매 배색 7부 티셔츠(JH2TSU064)   18000      NaN
# 19                             [홈플러스]simplus_냉동체리칠레산_500G    5990      NaN
# 20                       로즈민소매원피스 1025139 DRESS 쉬폰 레이스원피스   93370      NaN
# 21         [르오트] (TV홈쇼핑방송/무료배송) 쿨링시크 냉감 밴딩 팬츠-사이즈 55∼88다양    5900      NaN
# 22                         [ 빈 ] BT21TS05GN남아 포켓배색 그린 티셔츠   48000      NaN
# 23                            [올리비아하슬러]OH8MJP104 네크 셔링 점퍼   79900      NaN
# 24      [청정원] 병아리콩 빈달루 커리소스 360g 빈달루카레소스 병커리 인도식커리 커리소...   18170      NaN
# 25                       [반에이크]루즈핏 후드 티셔츠(VA94TSQ349Z_DG)   39800      NaN
# 26                               SOUP 벨트 숏 트렌치 코트 SV4BB90   87000      NaN
# 27                                   지오다노 슬림핏 치노팬츠 117922   15000      NaN
# 28                            [바보사랑]쿠츠와 제트스트림3 푸마 3색펜 0.5    9000   9000.0
# 29                                            두마리후라이드반반치킨   14990  14990.0
# ...                                                   ...     ...      ...
# 298820         [행텐] 남성 5부 포켓 티셔츠 (10170-031-461-05) NC아울렛   19800      NaN
# 298821  [크로커다일레이디스][크로커다일레이디] 코트 CL9MCT102_BL (P000577...  129500      NaN
# 298822                    [에꼴][18년 겨울]소매퍼 울코트(C91WCA001Z)  383200      NaN
# 298823                  [모다아울렛][페리미츠]쿨맥스 옐로우티셔츠 P1825T533    9300      NaN
# 298824                               클리오 도라에몽 민트치약 80g x1    3500   3500.0
# 298825                   [모다아울렛][앤듀](앤듀)홑겹 항공점퍼O185Z1001P   49000      NaN
# 298826                          [스미스마켓] 모스키노 페이던트 구두 여성구두   77000      NaN
# 298827              CP컴퍼니 19SS 06CMSS051A 103 렌즈 트레이닝 반바지  185480      NaN
# 298828                                베이직 더블자켓 SV1JK37/ 숲   99500      NaN
# 298829                   [캉골][AK분당점][캉골]키치 심볼 티셔츠 2592 네온   52000      NaN
# 298830        헤지스골프 남성 블랙 컬러블록 반팔카라티셔츠 HUTS9B316BK/ 헤지스골프  142200      NaN
# 298831        [마인드브릿지]마인드브릿지 CP스판섭섭만세와펜포켓세미오버티셔츠 MTTS3163   39900      NaN
# 298832  디스퀘어드2 셔츠(소매데님)프린팅 남방 중고 구제 캐주얼 배색 봄 가을 기본 남성용...   48000      NaN
# 298833        [흄(HUM)]W몰 HUM 남여공용 코치자켓 바람막이점퍼 FHMECUV702P   10000      NaN
# 298834  남성야상 남성점퍼 남자 야상점퍼 자켓 잠바 바람막이 숏 롱 간절기용 겨울용 탈부착 ...   92980      NaN
# 298835  (color : NAVY | size : L_100) 체크 패턴 배색 데님 네이비 ...   37580      NaN
# 298836                                   [젤리스푼]플라워롱티셔츠상하복   17900      NaN
# 298837    [오가게/아이우먼]아이우먼 밴딩 롤업 슬림핏진 MD4929M904 빅사이즈/ 아이우먼   46550      NaN
# 298838                        [르샵] 일자핏 허리밴딩 면바지(LJ2PT607)   71100      NaN
# 298839                    [SOUP]뒷판 자수 바람막이 후드 점퍼(SV4UJ90)   99000      NaN
# 298840  (사이즈 : M) JDP-068 베이직컬 하프팬츠-그레이 남성구제청바지 데님반바지 ...   30420      NaN
# 298841  자양윤모 샴푸 샴푸 2종(지성두피용) 머리샴푸 머릿결관리 손상모발샴푸 머릿결샴푸 헤어관리   35620      NaN
# 298842                              [남해바다] 전복 1kg(13~15미)   65900  65900.0
# 298843  (옵션1 : 블랙-1) 804S 줄지 슬림 스커트 DCM1927 여성패션스커트 패션...   33360      NaN
# 298844  (색상 : 흰색 | 사이즈 : FREE) MTS-358 싱포 맨투맨 남성맨투맨티셔츠...   15420      NaN
# 298845  [플레이키즈][플레이키즈프로][130-170] NSW 테크폴리스 여아 후디 (AMF...   89000      NaN
# 298846            (더아이잗컬렉션) 프릴끈 장식 블라우스 CJ4A0BL42/ 아이잗컬렉션  169000      NaN
# 298847  (color : Mblue | size : L_100) 핸리넥 데님 블루 셔츠 _N...   37580      NaN
# 298848                                         함초 자연소금3kg   19100  19100.0
# 298849            [포에버21]디스트로이드 슬림핏 청바지/FOREVER21/청바지/일자핏   37000      NaN
#
#             7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10     -120.0
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        0.0
# 29        0.0
# ...       ...
# 298820    NaN
# 298821    NaN
# 298822    NaN
# 298823    NaN
# 298824    0.0
# 298825    NaN
# 298826    NaN
# 298827    NaN
# 298828    NaN
# 298829    NaN
# 298830    NaN
# 298831    NaN
# 298832    NaN
# 298833    NaN
# 298834    NaN
# 298835    NaN
# 298836    NaN
# 298837    NaN
# 298838    NaN
# 298839    NaN
# 298840    NaN
# 298841    NaN
# 298842    0.0
# 298843    NaN
# 298844    NaN
# 298845    NaN
# 298846    NaN
# 298847    NaN
# 298848    0.0
# 298849    NaN
#
# [7972751 rows x 8 columns]

# %%
for x in pd.date_range('2019-04-02', periods=29):
    date = x.strftime('%Y-%m-%d')
    filename = "{}.csv".format(date)
    
    filepath = os.path.join(DATASET_PATH.filename)
    df = pd.read_csv(filepath, header=None, error_bad_lines=False, encoding = 'utf-8')
    o_df = o_df.append(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-221-add9a305950a> in <module>
#       3     filename = "{}.csv".format(date)
#       4
# ----> 5     filepath = os.path.join(DATASET_PATH.filename)
#       6     df = pd.read_csv(filepath, header=None, error_bad_lines=False, encoding = 'utf-8')
#       7     o_df = o_df.append(df)
#
# AttributeError: 'str' object has no attribute 'filename'

# %%
o_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-199-2b9b99dbd666> in <module>
# ----> 1 o_df.info()
#
# NameError: name 'o_df' is not defined

# %%
day = '01'

df = pd.read_csv(os.path.join(DATASET_PATH, '2019-04-01.csv'),  encoding = 'utf-8', error_bad_lines=False, header=None )

# %%
int('01')
# Out:
# 1

# %%
#킷헙 코드 찾는법
#검색 후 -> awesome-machine~ : best code - python!

#stackoerflow
